# %% [markdown]
# <a href="https://colab.research.google.com/github/pesado-dev/curso_de_dados/blob/main/C%C3%B3pia_de_estatistica_descritiva_case1_playground.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SETUP

# %%
# %pip install sidetable #sidetable a instalação faz com porcentagem
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sidetable
#   Downloading sidetable-0.9.1-py3-none-any.whl (19 kB)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.9/dist-packages (from sidetable) (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0->sidetable) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0->sidetable) (2022.7.1)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.0->sidetable) (1.22.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas>=1.0->sidetable) (1.16.0)
# Installing collected packages: sidetable
# Successfully installed sidetable-0.9.1

# %% [markdown]
# ## Load libraries

# %%
import numpy as np
import pandas as pd
import sidetable
from scipy import stats

import seaborn as sns
import matplotlib.pyplot as plt

import plotly.express as px

from ipywidgets import interact#essa biblioteca serve para tornar algumas funções interativas/adicionar no resumo

# %% [markdown]
# ## Custom settings

# %%
# https://matplotlib.org/stable/tutorials/introductory/customizing.html
sns.set_theme(
    context='talk',
    style='ticks',
    font_scale=.8, # codigo de costumização
    palette='viridis',
    rc={
        'figure.figsize': (12,8),
        'axes.grid': True,
        'grid.alpha': .2,
        'axes.titlesize': 'x-large',
        'axes.titleweight': 'bold',
        'axes.titlepad': 20,
    }
)

# %% [markdown]
# ## Custom functions

# %% [markdown]
# ## Load dataset

# %%
#dados pelo link também dá
DATA_URL = 'https://raw.githubusercontent.com/cmcouto-silva/datasets/main/datasets/ds_salaries.csv'

# %%
df = pd.read_csv(DATA_URL, index_col=0)
print(df.shape)
df.head()
# Out:
# (607, 11)
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# 3               HN            S
# 4               US            L

# %%
#treinando rodando data frame pelo link
df = pd.read_csv(DATA_URL,index_col=0)
print(df.shape)
df.head()
# Out:
# (607, 11)
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# 3               HN            S
# 4               US            L

# %% [markdown]
# # EDA

# %% [markdown]
# ## Verificando tipos de variáveis

# %% [markdown]
# Checar variáveis e consumo de memória

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 565 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           565 non-null    category
#  1   experience_level    565 non-null    category
#  2   employment_type     565 non-null    category
#  3   job_title           565 non-null    category
#  4   salary              565 non-null    int64
#  5   salary_currency     565 non-null    category
#  6   salary_in_usd       565 non-null    int64
#  7   employee_residence  565 non-null    category
#  8   remote_ratio        565 non-null    category
#  9   company_location    565 non-null    category
#  10  company_size        565 non-null    category
# dtypes: category(9), int64(2)
# memory usage: 27.1 KB

# %%
#treinando extraindo informações do data frame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 565 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           565 non-null    category
#  1   experience_level    565 non-null    category
#  2   employment_type     565 non-null    category
#  3   job_title           565 non-null    category
#  4   salary              565 non-null    int64
#  5   salary_currency     565 non-null    category
#  6   salary_in_usd       565 non-null    int64
#  7   employee_residence  565 non-null    category
#  8   remote_ratio        565 non-null    category
#  9   company_location    565 non-null    category
#  10  company_size        565 non-null    category
# dtypes: category(9), int64(2)
# memory usage: 27.1 KB

# %%
#treinando somando memory usage
memory_usage1=df.memory_usage().sum()

# %%
#treinando mudando tipo do dados
categorical_columns=df.columns[df.dtypes==object].tolist()+['work_year','remote_ratio']
#treinando salvando dentro de um categoria
df[categorical_columns]=df[categorical_columns].astype('category')
#se tiver em objeto o tipo de dado, vale a pena converter para categoria para consumir menos dados

# %%
#treinando validando nulos e duplicados
df.isna().sum().any()
# Out:
# False

# %%
#treinando validando nulos e duplicados
#vendo valores duplicados
df.duplicated().sum()
# Out:
# 42

# %%
#treinando validando nulos e duplicados
df[df.duplicated(keep=False)].sort_values(df.columns.tolist())
# Out:
#     work_year experience_level employment_type                  job_title  \
# 119      2021               MI              FT              Data Engineer
# 256      2021               MI              FT              Data Engineer
# 181      2021               MI              FT             Data Scientist
# 217      2021               MI              FT             Data Scientist
# 367      2022               MI              FT               Data Analyst
# ..        ...              ...             ...                        ...
# 592      2022               SE              FT             Data Scientist
# 372      2022               SE              FT  Machine Learning Engineer
# 439      2022               SE              FT  Machine Learning Engineer
# 371      2022               SE              FT  Machine Learning Engineer
# 438      2022               SE              FT  Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence remote_ratio  \
# 119  200000             USD         200000                 US          100
# 256  200000             USD         200000                 US          100
# 181   76760             EUR          90734                 DE           50
# 217   76760             EUR          90734                 DE           50
# 367   58000             USD          58000                 US            0
# ..      ...             ...            ...                ...          ...
# 592  230000             USD         230000                 US          100
# 372  164996             USD         164996                 US            0
# 439  164996             USD         164996                 US            0
# 371  189650             USD         189650                 US            0
# 438  189650             USD         189650                 US            0
#
#     company_location company_size
# 119               US            L
# 256               US            L
# 181               DE            L
# 217               DE            L
# 367               US            S
# ..               ...          ...
# 592               US            M
# 372               US            M
# 439               US            M
# 371               US            M
# 438               US            M
#
# [71 rows x 11 columns]

# %%
#treinando validando nulos e duplicados
#limpando dados duplicados
df.drop_duplicates(inplace=True)

# %%
#treinando analise univariada
df.select_dtypes('number').describe()
# Out:
#              salary  salary_in_usd
# count  5.650000e+02     565.000000
# mean   3.381160e+05  110610.343363
# std    1.599879e+06   72280.702792
# min    4.000000e+03    2859.000000
# 25%    6.700000e+04   60757.000000
# 50%    1.109250e+05  100000.000000
# 75%    1.650000e+05  150000.000000
# max    3.040000e+07  600000.000000

# %%
#treinando analise univariada
df.select_dtypes('category').describe()
# Out:
#         work_year experience_level employment_type       job_title  \
# count         565              565             565             565
# unique          3                4               4              50
# top          2022               SE              FT  Data Scientist
# freq          278              243             546             130
#
#        salary_currency employee_residence  remote_ratio company_location  \
# count              565                565           565              565
# unique              17                 57             3               50
# top                USD                 US           100               US
# freq               359                295           346              318
#
#        company_size
# count           565
# unique            3
# top               M
# freq            290

# %%
#treinando analise univariada
df.experience_level.value_counts()
# Out:
# SE    243
# MI    208
# EN     88
# EX     26
# Name: experience_level, dtype: int64

# %%
#treinando analise univariada
df_count=df.stb.freq(['experience_level'])

# %%
#treinando analise univariada

for categorical_column in categorical_columns:
  print(f'##--{categorical_column}--##')
  display(df.stb.freq(['experience_level']))
  print()
# Out:
# ##--experience_level--##
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000
# ##--employment_type--##
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000
# ##--job_title--##
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000
# ##--salary_currency--##
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000
# ##--employee_residence--##
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000
# ##--company_location--##
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000
# ##--company_size--##
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000
# ##--work_year--##
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000
# ##--remote_ratio--##
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000

# %%
#treinando gráficos
px.pie(df_count, values='count',names='experience_level')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="3742d668-bc9e-4dab-a446-2b25bc00dd2d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3742d668-bc9e-4dab-a446-2b25bc00dd2d")) {                    Plotly.newPlot(                        "3742d668-bc9e-4dab-a446-2b25bc00dd2d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"experience_level=%{label}<br>count=%{value}<extra></extra>","labels":["SE","MI","EN","EX"],"legendgroup":"","name":"","showlegend":true,"values":[243,208,88,26],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","s ...

# %%
#gera vários gráficos no mesmo código
#treinando gráficos
@interact(categorical_column=categorical_columns)
def pie_plot(categorical_column):
  df_count=df.stb.freq([categorical_column])
  fig=px.pie(df_count, values='count',names=categorical_column)
  fig.update_layout(title=dict(text=f'{categorical_column}',x=.5))
  fig.show()
# Out:
# interactive(children=(Dropdown(description='categorical_column', options=('experience_level', 'employment_type…

# %%
#treinando histograma-boxplot
fig,axes=plt.subplots(ncols=2,figsize=(18,8))
sns.boxplot(data=df,x='salary_in_usd',ax=axes[0])
sns.histplot(data=df,x='salary_in_usd',kde=True,ax=axes[1])
sns.despine()

plt.show()

# %%
#treinando histograma-boxplot
stats.skew(df.salary_in_usd)#está mais para esquerda
# Out:
# 1.6634213360977623

# %%
#treinando histograma-boxplot
stats.kurtosis(df.salary_in_usd)#está mais elevado
# Out:
# 6.291709208027671

# %%
#treinando Ánalise multivariada
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# 3               HN            S
# 4               US            L

# %%
#treinando Ánalise multivariada
sns.boxplot(data=df,x='experience_level',y='salary_in_usd',hue='company_size',
            order=['EN','MI','SE','EX'],hue_order=['S','M','L'],showmeans=True
            )
# Out:
# <Axes: xlabel='experience_level', ylabel='salary_in_usd'>

# %%
#treinando Ánalise multivariada
sns.barplot(data=df,x='company_size',y='salary_in_usd',order=['S','M','L'])
# Out:
# <Axes: xlabel='company_size', ylabel='salary_in_usd'>

# %%
#treinando Ánalise multivariada
crosstab=(
    pd.crosstab(df['experience_level'],df['company_size'])
    .loc[['EN','MI','SE','EX'],['S','M','L']]
    )
crosstab
# Out:
# company_size       S    M   L
# experience_level
# EN                29   30  29
# MI                29   98  86
# SE                22  186  72
# EX                 3   12  11

# %%
#treinando Ánalise multivariada
stats.contingency.association(crosstab)#calculando a cotigencia
# Out:
# 0.2168376140678209

# %%
#treinando Ánalise multivariada

chi2,p,dof,expected=stats.chi2_contingency(crosstab)#calculando chiq2
expected
# Out:
# array([[ 12.03294893,  47.26194399,  28.70510708],
#        [ 29.12520593, 114.39538715,  69.47940692],
#        [ 38.28665568, 150.37891269,  91.33443163],
#        [  3.55518946,  13.96375618,   8.48105437]])

# %%
#treinando Ánalise multivariada

(crosstab-expected).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_28413_row0_col0, #T_28413_row1_col2, #T_28413_row2_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_28413_row0_col1, #T_28413_row2_col0, #T_28413_row2_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_28413_row0_col2 {
#   background-color: #f6583e;
#   color: #f1f1f1;
# }
# #T_28413_row1_col0 {
#   background-color: #fb6e4e;
#   color: #f1f1f1;
# }
# #T_28413_row1_col1 {
#   background-color: #fff2ec;
#   color: #000000;
# }
# #T_28413_row3_col0 {
#   background-color: #fb7252;
#   color: #f1f1f1;
# }
# #T_28413_row3_col1 {
#   background-color: #fcae92;
#   color: #000000;
# }
# #T_28413_row3_col2 {
#   background-color: #f0402f;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_28413" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >company_size</th>
#       <th id="T_28413_level0_col0" class="col_heading level0 col0" >S</th>
#       <th id="T_28413_level0_col1" class="col_heading level0 col1" >M</th>
#       <th id="T_28413_level0_col2" class="col_heading level0 col2" >L</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >experience_level</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_28413_level0_row0" class="row_heading level0 row0" >EN</th>
#       <td id="T_28413_row0_col0" class="data row0 col0" >16.967051</td>
#       <td id="T_28413_row0_col1" class="data row0 col1" >-17.261944</td>
#       <td id="T_28413_row0_col2" class="data row0 col2" >0.294893</td>
#     </tr>
#     <tr>
#       <th id="T_28413_level0_row1" class="row_heading level0 row1" >MI</th>
#       <td id="T_28413_row1_col0" class="data row1 col0" >-0.125206</td>
#       <td id="T_28413_row1_col1" class="data row1 col1" >-16.395387</td>
#       <td id="T_28413_row1_col2" class="data row1 col2" >16.520593</td>
#     </tr>
#     <tr>
#       <th id="T_28413_level0_row2" class="row_heading level0 row2" >SE</th>
#       <td id="T_28413_row2_col0" class="data row2 col0" >-16.286656</td>
#       <td id="T_28413_row2_col1" class="data row2 col1" >35.621087</td>
#       <td id="T_28413_row2_col2" class="data row2 col2" >-19.334432</td>
#     </tr>
#     <tr>
#       <th id="T_28413_level0_row3" class="row_heading level0 row3" >EX</th>
#       <td id="T_28413_row3_col0" class="data row3 col0" >-0.555189</td>
#       <td id="T_28413_row3_col1" class="data row3 col1" >-1.963756</td>
#       <td id="T_28413_row3_col2" class="data row3 col2" >2.518946</td>
#     </tr>
#   </tbody>
# </table>

# %%
#treinando Ánalise multivariada
sns.histplot(data=df,x='salary_in_usd',hue='experience_level',palette='tab10',alpha=.4,kde=True)
# Out:
# <Axes: xlabel='salary_in_usd', ylabel='Count'>

# %%
#treinando Ánalise multivariada
@interact (x=df.columns.tolist(),hue=df.columns.tolist())
def plot(x,hue):
  sns.histplot(data=df,x=x,hue=hue,palette='tab10',alpha=.4)
  plt.title(f'{x} by {hue}')
  sns.despine()
  plt.show()
# Out:
# interactive(children=(Dropdown(description='x', options=('work_year', 'experience_level', 'employment_type', '…

# %%
#treinando Ánalise multivariada
px.box(df,x='remote_ratio',y='salary_in_usd')#chamando função px.box,entre parenteses variavel,x a coluna desejavel e y tambem
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="cfd18ad0-4e4b-46b7-ad17-bbfe691cd019" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cfd18ad0-4e4b-46b7-ad17-bbfe691cd019")) {                    Plotly.newPlot(                        "cfd18ad0-4e4b-46b7-ad17-bbfe691cd019",                        [{"alignmentgroup":"True","hovertemplate":"remote_ratio=%{x}<br>salary_in_usd=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":[0,0,50,0,50,100,100,50,100,50,0,0,0,100,100,50,100,100,50,100,0,100,50,0,0,100,50,0,100,50,100,100,100,0,50,50,100,50,100,100,100,50,0,100,50,100,100,100,100,50,0,100,50,100,100,100,100,100,50,100,100,100,50,100,100,50,0,100,100,0,50,50,50,100,100,50,100,50,100,100,100,100,50,100,100,100,50,100,100,100,100,100,100,0,50,50,100,100,100,100,0,100,50,0,0,50,100,100,100,100,50,100,100,100,100,100,100,100,100,100,50,100,100,0,50,100,50,0,100,50,50,50,100,100,0,100,50,50,0,100,100,0,0,100,100,50,50,100,100,100,0,100,100,100,100,50,100,50,100,100,50,0,50,50,50,100,100,0,50,100,100,100,100,100,50,100,0,100,50,100,0,50,0,50,50,100,100,100,50,50,100,50,0,100,50,50,100,100,50,100,50,100,100,100,100,0,100,0,0,0,50,50,50,0,50,100,50,50,100,100,100,50,0,50,100,100,100,50,0,100,100,100,100,100,100,0,100,100,0,50,100,100,100,100,100,50,50,0,50,100,50,100,100,100,100,50,100,100,50,0,50,50,100,0,100,50,0,0,100,50,100,0,0,100,50,100,50,100,50,100,100,0,100,100,50,50,100,50,50,100,100,100,0,0,100,100,100,100,100,100,0,0,100,100,100,0,0,0,0,100,100,0,0,0,0,100,100,100,100,0,0,0,0,0,0,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,0,0,0,100,100,100,100,100,0,0,0,100,100,100,100,100,100,100,0,100,0,0,100,100,100,0,0,0,0,100,0,100,100,100,100,100,100,100,50,100,100,0,100,0,0,0,100,100,100,100,100,0,100,100,100,100,0,0,100,0,0,100,100,100,0,0,100,100,100,100,100,100,0,100,100,100,100,0,0,0,100,100,0,100,100,100,100,100,100,100,100,100,0,0,100,100,100,100,0,100,100,100,100,100,100,100,50,100,0,50,100,0,100,100,50,50,50,100,100,100,50,100,100,100,100,100,100,100,0,0,100,100,100,100,100,100,100,100,100,100,100,50,100,100,100,100,100,100,100,50,100,100,50,100,100,100,100,100,100,50,100,0,100,100,100,50,100,100,0,100,100,100,0,100,100,100,100,100,100,100,100,100,100,100,0,0,100,100,100,100,100,100,0,0,100,100,0,0,100,100,100,100,100,100,0,0,100,100,100,100,100,0,0,0,0,0,100,100,100,0,100,0,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,0,100,0,100,100,100,100,100,100,100,100,100,100,100,0,0,100,100,0,100,100],"x0":" ","xaxis":"x","y":[79833,260000,109024,20000,150000,72000,190000,35735,135000,125000,51321,40481,39916,87000,85000,8000,41689,114047,5707,56000,43331,6072,47899,98000,115000,325000,42000,33511,100000,117104,59303,70000,68428,450000,46759,74130,103000,250000,10000,138000,45760,79833,50180,106000,112872,15966,76958,188000,105000,70139,6072,91000,45896,54742,60000,148261,38776,118000,120000,138350,110000,130800,21669,412000,45618,62726,49268,190200,105000,91237,62726,42197,82528,150000,235000,53192,100000,5409,270000,80000,79197,140000,54238,47282,153667,28476,59102,110000,170000,80000,88654,76833,19609,276000,29751,89294,12000,450000,70000,95746,75000,150000,36259,62000,73000,51519,187442,115000,150000,30428,94564,113476,103160,12000,45391,225000,50000,40189,90000,200000,60000,200000,50000,110037,10354,151000,120000,9466,20000,40570,100000,49646,38400,24000,100000,90000,63711,77364,220000,80000,135000,240000,150000,82500,100000,82744,62649,90000,153000,160000,168000,150000,75774,13400,144000,127221,119059,423000,120000,125000,230000,85000,28369,63831,130026,165000,80000,250000,55000,150000,170000,82528,60000,235000,60757,174 ...

# %%
df.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               MI              FT              Data Scientist
# 1       2020               SE              FT  Machine Learning Scientist
# 2       2020               SE              FT           Big Data Engineer
# 3       2020               MI              FT        Product Data Analyst
# 4       2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0   70000             EUR          79833                 DE             0
# 1  260000             USD         260000                 JP             0
# 2   85000             GBP         109024                 GB            50
# 3   20000             USD          20000                 HN             0
# 4  150000             USD         150000                 US            50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# 3               HN            S
# 4               US            L

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    category
#  1   experience_level    607 non-null    category
#  2   employment_type     607 non-null    category
#  3   job_title           607 non-null    category
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    category
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    category
#  8   remote_ratio        607 non-null    category
#  9   company_location    607 non-null    category
#  10  company_size        607 non-null    category
# dtypes: category(9), int64(2)
# memory usage: 28.4 KB

# %%
memory_usage1 = df.memory_usage().sum()

# %%
categorical_columns = df.columns[df.dtypes==object].tolist() + ['work_year', 'remote_ratio']
df[categorical_columns] = df[categorical_columns].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    category
#  1   experience_level    607 non-null    category
#  2   employment_type     607 non-null    category
#  3   job_title           607 non-null    category
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    category
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    category
#  8   remote_ratio        607 non-null    category
#  9   company_location    607 non-null    category
#  10  company_size        607 non-null    category
# dtypes: category(9), int64(2)
# memory usage: 28.4 KB

# %%
memory_usage2 = df.memory_usage().sum()

# %%
1 - memory_usage2 / memory_usage1
# Out:
# 0.5007035969247666

# %% [markdown]
# ## Validando nulos e duplicados

# %%
df.isna().sum().any()
# Out:
# False

# %%
df.duplicated().sum()
# Out:
# 42

# %%
df[df.duplicated(keep=False)].sort_values(df.columns.tolist())
# Out:
#     work_year experience_level employment_type                  job_title  \
# 119      2021               MI              FT              Data Engineer
# 256      2021               MI              FT              Data Engineer
# 181      2021               MI              FT             Data Scientist
# 217      2021               MI              FT             Data Scientist
# 367      2022               MI              FT               Data Analyst
# ..        ...              ...             ...                        ...
# 592      2022               SE              FT             Data Scientist
# 372      2022               SE              FT  Machine Learning Engineer
# 439      2022               SE              FT  Machine Learning Engineer
# 371      2022               SE              FT  Machine Learning Engineer
# 438      2022               SE              FT  Machine Learning Engineer
#
#      salary salary_currency  salary_in_usd employee_residence remote_ratio  \
# 119  200000             USD         200000                 US          100
# 256  200000             USD         200000                 US          100
# 181   76760             EUR          90734                 DE           50
# 217   76760             EUR          90734                 DE           50
# 367   58000             USD          58000                 US            0
# ..      ...             ...            ...                ...          ...
# 592  230000             USD         230000                 US          100
# 372  164996             USD         164996                 US            0
# 439  164996             USD         164996                 US            0
# 371  189650             USD         189650                 US            0
# 438  189650             USD         189650                 US            0
#
#     company_location company_size
# 119               US            L
# 256               US            L
# 181               DE            L
# 217               DE            L
# 367               US            S
# ..               ...          ...
# 592               US            M
# 372               US            M
# 439               US            M
# 371               US            M
# 438               US            M
#
# [71 rows x 11 columns]

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# # Análise univariada

# %% [markdown]
# Análise univariada com variáveis numéricas e categóricas, separadamente.

# %%
df.select_dtypes('number').describe()
# Out:
#              salary  salary_in_usd
# count  5.650000e+02     565.000000
# mean   3.381160e+05  110610.343363
# std    1.599879e+06   72280.702792
# min    4.000000e+03    2859.000000
# 25%    6.700000e+04   60757.000000
# 50%    1.109250e+05  100000.000000
# 75%    1.650000e+05  150000.000000
# max    3.040000e+07  600000.000000

# %%
df.select_dtypes('category').describe()
# Out:
#         work_year experience_level employment_type       job_title  \
# count         565              565             565             565
# unique          3                4               4              50
# top          2022               SE              FT  Data Scientist
# freq          278              243             546             130
#
#        salary_currency employee_residence  remote_ratio company_location  \
# count              565                565           565              565
# unique              17                 57             3               50
# top                USD                 US           100               US
# freq               359                295           346              318
#
#        company_size
# count           565
# unique            3
# top               M
# freq            290

# %% [markdown]
# Tabela de frequência para todas variáveis categóricas

# %%
df.experience_level.value_counts()
# Out:
# SE    243
# MI    208
# EN     88
# EX     26
# Name: experience_level, dtype: int64

# %%
df.stb.freq(['experience_level'])
# Out:
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000

# %%
for categorical_column in categorical_columns:
  print(f'## -- {categorical_column} -- ##')
  display(df.stb.freq(['experience_level']))
  print()
# Out:
# ## -- experience_level -- ##
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000
# ## -- employment_type -- ##
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000
# ## -- job_title -- ##
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000
# ## -- salary_currency -- ##
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000
# ## -- employee_residence -- ##
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000
# ## -- company_location -- ##
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000
# ## -- company_size -- ##
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000
# ## -- work_year -- ##
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000
# ## -- remote_ratio -- ##
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000

# %% [markdown]
# ## Gráficos

# %% [markdown]
# ### Variáveis categóricas

# %% [markdown]
# Gráfico de pizza e de barras + versão interativa

# %%
df_count = df.stb.freq(['experience_level'])
df_count
# Out:
#   experience_level  count    percent  cumulative_count  cumulative_percent
# 0               SE    243  43.008850               243           43.008850
# 1               MI    208  36.814159               451           79.823009
# 2               EN     88  15.575221               539           95.398230
# 3               EX     26   4.601770               565          100.000000

# %%
px.pie(df_count, values='count', names='experience_level')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="935431fb-71c4-42e9-b9b9-2058a64e2dd8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("935431fb-71c4-42e9-b9b9-2058a64e2dd8")) {                    Plotly.newPlot(                        "935431fb-71c4-42e9-b9b9-2058a64e2dd8",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"experience_level=%{label}<br>count=%{value}<extra></extra>","labels":["SE","MI","EN","EX"],"legendgroup":"","name":"","showlegend":true,"values":[243,208,88,26],"type":"pie"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scatterc ...

# %%
@interact(categorical_column=['experience_level', 'employment_type', 'remote_ratio', 'company_size'])
def pie_plot(categorical_column):
  df_count = df.stb.freq([categorical_column])
  fig = px.pie(df_count, values='count', names=categorical_column)
  fig.update_layout(title=dict(text=f'<b>{categorical_column}</b>', x=.5))
  fig.show()
# Out:
# interactive(children=(Dropdown(description='categorical_column', options=('experience_level', 'employment_type…

# %%
@interact(categorical_column=categorical_columns)
def bar_plot(categorical_column):
  df_count = df.stb.freq([categorical_column])
  fig = px.bar(df_count, y='count', x=categorical_column)
  fig.update_layout(title=dict(text=f'<b>{categorical_column}</b>', x=.5))
  fig.show()
# Out:
# interactive(children=(Dropdown(description='categorical_column', options=('experience_level', 'employment_type…

# %% [markdown]
# ### Variáveis numéricas

# %% [markdown]
# Histograma + Boxplot

# %%
fig,axes = plt.subplots(ncols=2, figsize=(18,8), gridspec_kw={'width_ratios':[.1,.9]})

sns.boxplot(data=df, y='salary_in_usd', ax=axes[0])
sns.histplot(data=df, x='salary_in_usd', kde=True, ax=axes[1])
sns.despine()

plt.show()

# %%
stats.skew(df.salary_in_usd)
# Out:
# 1.7282336070348854

# %%
stats.kurtosis(df.salary_in_usd)
# Out:
# 6.38414589529744

# %% [markdown]
# # Análise Multivariada

# %%
df.head()
# Out:
#   work_year experience_level employment_type                   job_title  \
# 0      2020               MI              FT              Data Scientist
# 1      2020               SE              FT  Machine Learning Scientist
# 2      2020               SE              FT           Big Data Engineer
# 3      2020               MI              FT        Product Data Analyst
# 4      2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence remote_ratio  \
# 0   70000             EUR          79833                 DE            0
# 1  260000             USD         260000                 JP            0
# 2   85000             GBP         109024                 GB           50
# 3   20000             USD          20000                 HN            0
# 4  150000             USD         150000                 US           50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# 3               HN            S
# 4               US            L

# %%
px.box?

# %%
df2 = df.copy()
df2['experience_level'] = df2.experience_level.astype(str)

# %%
px.box?

# %%
px.box(df2, x='experience_level', y='salary_in_usd', category_orders=['EN','MI','SE','EX'])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="f856f65c-d061-40f2-902a-11eb233795a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f856f65c-d061-40f2-902a-11eb233795a4")) {                    Plotly.newPlot(                        "f856f65c-d061-40f2-902a-11eb233795a4",                        [{"alignmentgroup":"True","hovertemplate":"experience_level=%{x}<br>salary_in_usd=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["MI","SE","SE","MI","SE","EN","SE","MI","MI","SE","EN","MI","EN","MI","MI","MI","EN","SE","EN","MI","MI","MI","SE","MI","MI","EX","EN","SE","EN","SE","MI","EN","SE","MI","MI","MI","MI","EN","EN","EN","MI","EX","MI","MI","MI","EN","MI","SE","MI","MI","EN","EN","EN","EN","SE","SE","MI","MI","SE","MI","MI","MI","EN","SE","SE","EN","EN","SE","EN","SE","MI","MI","EN","EX","EX","SE","MI","MI","MI","EN","SE","MI","MI","MI","EX","MI","EN","MI","SE","SE","SE","EN","MI","SE","EN","MI","EN","MI","EN","MI","MI","SE","MI","MI","MI","MI","MI","SE","SE","EN","SE","SE","SE","EN","MI","EN","MI","MI","EN","MI","MI","SE","EN","EN","EN","MI","SE","MI","EN","SE","EN","EN","MI","SE","EN","MI","MI","MI","SE","EN","MI","SE","SE","MI","MI","SE","MI","MI","SE","SE","SE","MI","MI","EN","SE","SE","MI","MI","SE","EN","EX","EX","MI","EN","EX","SE","EN","EX","EN","MI","MI","MI","EN","SE","SE","SE","MI","MI","EN","MI","MI","MI","MI","SE","MI","MI","SE","EX","SE","MI","SE","EN","MI","SE","SE","MI","EN","SE","SE","EN","MI","SE","MI","SE","MI","MI","SE","SE","MI","SE","MI","MI","MI","EN","EN","SE","EN","MI","SE","MI","MI","MI","MI","SE","EX","SE","MI","SE","SE","EN","SE","SE","SE","MI","MI","MI","MI","EN","EN","SE","MI","MI","SE","EN","MI","EN","MI","SE","SE","MI","EN","EX","EN","MI","SE","SE","SE","EX","MI","SE","MI","SE","MI","SE","MI","MI","MI","EN","EN","SE","EN","EN","SE","EN","EN","SE","SE","EN","MI","EN","MI","SE","MI","SE","SE","MI","MI","SE","SE","SE","MI","MI","MI","MI","SE","SE","SE","SE","SE","SE","SE","SE","EN","SE","SE","MI","MI","EX","EX","MI","MI","MI","MI","SE","EN","SE","SE","SE","SE","SE","SE","SE","SE","SE","EX","EX","SE","MI","SE","SE","SE","MI","SE","SE","SE","SE","SE","EX","EX","EX","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","MI","EX","SE","SE","SE","MI","EX","SE","SE","SE","SE","SE","SE","SE","EX","EN","SE","SE","MI","MI","MI","SE","SE","MI","MI","SE","SE","SE","SE","SE","SE","SE","MI","SE","MI","SE","MI","MI","MI","MI","MI","MI","SE","SE","MI","MI","MI","MI","MI","SE","SE","MI","SE","MI","SE","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","MI","SE","MI","SE","EN","SE","MI","EX","MI","EN","MI","SE","SE","MI","MI","MI","EN","MI","EN","SE","EN","SE","SE","SE","SE","MI","MI","SE","MI","MI","SE","SE","MI","MI","SE","SE","EX","EX","SE","SE","SE","EN","MI","EN","SE","MI","MI","SE","SE","MI","EN","SE","SE","EN","SE","MI","EN","MI","SE","EN","MI","MI","EN","MI","EN","MI","EN","SE","EN","MI","SE","MI","MI","SE","MI","EN","MI","SE","MI","SE","MI","SE","MI","MI","SE","SE","SE","SE","MI","MI","SE","SE","MI","MI","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","MI","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","SE","MI","SE","SE","SE","SE","SE","SE","MI","MI","EN","EN","SE","SE","SE","SE","MI"],"x0":" ","xaxis":"x","y":[79833,260000,109024,20000,150000,72000,190000,35735,135000,125000,51321,40481,39916,87000,85000,8000,41689,114047,5707,56000,43331,6072,47899,98000,115000,325000,42000,33511,100000,117104,59303,70000,68428,450000,46759,74130,103000,250000,10000,138000,45760,79833,50180,106000,112872,15966,76958,188000,105000,70139,6072,91000,45896,54742,60000,148261,38776,118000,120 ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 565 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           565 non-null    category
#  1   experience_level    565 non-null    category
#  2   employment_type     565 non-null    category
#  3   job_title           565 non-null    category
#  4   salary              565 non-null    int64
#  5   salary_currency     565 non-null    category
#  6   salary_in_usd       565 non-null    int64
#  7   employee_residence  565 non-null    category
#  8   remote_ratio        565 non-null    category
#  9   company_location    565 non-null    category
#  10  company_size        565 non-null    category
# dtypes: category(9), int64(2)
# memory usage: 43.2 KB

# %%
sns.boxplot(
    data=df, x='experience_level', y='salary_in_usd', hue='company_size',
    order=['EN','MI','SE','EX'], hue_order=['S','M','L'], showmeans=True
    )

# %%
sns.barplot(data=df, x='company_size', y='salary_in_usd', order=['S','M','L'])

# %%
crosstab = (
    pd.crosstab(df['experience_level'], df['company_size'])
    .loc[['EN','MI','SE', 'EX'], ['S','M','L']]
    )
crosstab
# Out:
# company_size       S    M   L
# experience_level
# EN                29   30  29
# MI                28   96  84
# SE                22  152  69
# EX                 3   12  11

# %%
stats.contingency.association(crosstab)
# Out:
# 0.2168376140678209

# %%
chi2,p,dof,expected = stats.chi2_contingency(crosstab)
expectedLista
# Out:
# array([[ 12.77168142,  45.16814159,  30.06017699],
#        [ 30.18761062, 106.76106195,  71.05132743],
#        [ 35.26725664, 124.72566372,  83.00707965],
#        [  3.77345133,  13.34513274,   8.88141593]])

# %%
(crosstab - expected).style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_608ed_row0_col0, #T_608ed_row1_col2, #T_608ed_row2_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_608ed_row0_col1, #T_608ed_row2_col0, #T_608ed_row2_col2 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# #T_608ed_row0_col2 {
#   background-color: #fb7151;
#   color: #f1f1f1;
# }
# #T_608ed_row1_col0 {
#   background-color: #fc9272;
#   color: #000000;
# }
# #T_608ed_row1_col1 {
#   background-color: #fee4d8;
#   color: #000000;
# }
# #T_608ed_row3_col0 {
#   background-color: #fc8262;
#   color: #f1f1f1;
# }
# #T_608ed_row3_col1 {
#   background-color: #fca285;
#   color: #000000;
# }
# #T_608ed_row3_col2 {
#   background-color: #f14432;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_608ed_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="index_name level0" >company_size</th>
#       <th class="col_heading level0 col0" >S</th>
#       <th class="col_heading level0 col1" >M</th>
#       <th class="col_heading level0 col2" >L</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >experience_level</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_608ed_level0_row0" class="row_heading level0 row0" >EN</th>
#       <td id="T_608ed_row0_col0" class="data row0 col0" >16.228319</td>
#       <td id="T_608ed_row0_col1" class="data row0 col1" >-15.168142</td>
#       <td id="T_608ed_row0_col2" class="data row0 col2" >-1.060177</td>
#     </tr>
#     <tr>
#       <th id="T_608ed_level0_row1" class="row_heading level0 row1" >MI</th>
#       <td id="T_608ed_row1_col0" class="data row1 col0" >-2.187611</td>
#       <td id="T_608ed_row1_col1" class="data row1 col1" >-10.761062</td>
#       <td id="T_608ed_row1_col2" class="data row1 col2" >12.948673</td>
#     </tr>
#     <tr>
#       <th id="T_608ed_level0_row2" class="row_heading level0 row2" >SE</th>
#       <td id="T_608ed_row2_col0" class="data row2 col0" >-13.267257</td>
#       <td id="T_608ed_row2_col1" class="data row2 col1" >27.274336</td>
#       <td id="T_608ed_row2_col2" class="data row2 col2" >-14.007080</td>
#     </tr>
#     <tr>
#       <th id="T_608ed_level0_row3" class="row_heading level0 row3" >EX</th>
#       <td id="T_608ed_row3_col0" class="data row3 col0" >-0.773451</td>
#       <td id="T_608ed_row3_col1" class="data row3 col1" >-1.345133</td>
#       <td id="T_608ed_row3_col2" class="data row3 col2" >2.118584</td>
#     </tr>
#   </tbody>
# </table>

# %%
df.head()
# Out:
#   work_year experience_level employment_type                   job_title  \
# 0      2020               MI              FT              Data Scientist
# 1      2020               SE              FT  Machine Learning Scientist
# 2      2020               SE              FT           Big Data Engineer
# 3      2020               MI              FT        Product Data Analyst
# 4      2020               SE              FT   Machine Learning Engineer
#
#    salary salary_currency  salary_in_usd employee_residence remote_ratio  \
# 0   70000             EUR          79833                 DE            0
# 1  260000             USD         260000                 JP            0
# 2   85000             GBP         109024                 GB           50
# 3   20000             USD          20000                 HN            0
# 4  150000             USD         150000                 US           50
#
#   company_location company_size
# 0               DE            L
# 1               JP            S
# 2               GB            M
# 3               HN            S
# 4               US            L

# %%
@interact(x=df.columns.tolist(), hue=df.columns.tolist())
def plot(x, hue):
  sns.histplot(data=df, x=x, hue=hue, palette='tab10', alpha=.4)
  plt.title(f'{x} by {hue}')
  sns.despine()
  plt.show()
# Out:
# interactive(children=(Dropdown(description='x', options=('work_year', 'experience_level', 'employment_type', '…

# %%
px.box(df, x='remote_ratio', y='salary_in_usd')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7036d0d4-f359-43af-9571-e686689b136e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7036d0d4-f359-43af-9571-e686689b136e")) {                    Plotly.newPlot(                        "7036d0d4-f359-43af-9571-e686689b136e",                        [{"alignmentgroup":"True","hovertemplate":"remote_ratio=%{x}<br>salary_in_usd=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":[0,0,50,0,50,100,100,50,100,50,0,0,0,100,100,50,100,100,50,100,0,100,50,0,0,100,50,0,100,50,100,100,100,0,50,50,100,50,100,100,100,50,0,100,50,100,100,100,100,50,0,100,50,100,100,100,100,100,50,100,100,100,50,100,100,50,0,100,100,0,50,50,50,100,100,50,100,50,100,100,100,100,50,100,100,100,50,100,100,100,100,100,100,0,50,50,100,100,100,100,0,100,50,0,0,50,100,100,100,100,50,100,100,100,100,100,100,100,100,100,50,100,100,0,50,100,50,0,100,50,50,50,100,100,0,100,50,50,0,100,100,0,0,100,100,50,50,100,100,100,0,100,100,100,100,50,100,50,100,100,50,0,50,50,50,100,100,0,50,100,100,100,100,100,50,100,0,100,50,100,0,50,0,50,50,100,100,100,50,50,100,50,0,100,50,50,100,100,50,100,50,100,100,100,100,0,100,0,0,0,50,50,50,0,50,100,50,100,100,100,50,0,50,100,100,100,50,0,100,100,100,100,100,100,0,100,100,0,50,100,100,100,100,100,50,50,0,50,100,50,100,100,100,100,50,100,50,0,50,50,100,0,100,50,0,0,100,50,100,0,0,100,50,100,50,100,50,100,100,0,100,100,50,50,100,50,50,100,100,100,0,0,100,100,100,100,100,100,0,0,100,100,100,0,0,0,0,100,100,0,0,0,0,100,100,100,100,0,0,0,0,0,0,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,100,0,0,0,100,100,100,100,0,0,0,100,100,100,100,100,0,100,0,0,100,100,0,0,0,100,0,100,100,100,100,100,100,50,100,0,100,0,0,0,100,100,100,0,100,100,100,100,0,0,100,0,100,100,100,0,0,100,100,100,100,100,100,0,100,100,100,100,0,0,0,100,100,0,100,100,100,100,100,100,100,100,100,100,100,100,0,100,100,100,100,100,50,100,0,50,100,0,100,100,50,50,50,100,100,100,50,100,100,100,100,100,100,0,0,100,100,100,100,100,100,100,100,100,100,100,50,100,100,100,100,100,100,100,50,100,100,50,100,100,100,100,100,100,50,100,0,100,100,100,50,100,100,0,100,100,100,0,100,100,100,100,100,100,100,100,100,0,0,100,100,100,100,0,0,100,100,0,0,100,100,100,100,0,100,100,100,100,0,0,0,0,0,100,100,100,0,0,100,100,100,100,100,100,100,100,100,100,100,0,100,100,100,100,100,100,100,100,0,0,100,100,0,100,100],"x0":" ","xaxis":"x","y":[79833,260000,109024,20000,150000,72000,190000,35735,135000,125000,51321,40481,39916,87000,85000,8000,41689,114047,5707,56000,43331,6072,47899,98000,115000,325000,42000,33511,100000,117104,59303,70000,68428,450000,46759,74130,103000,250000,10000,138000,45760,79833,50180,106000,112872,15966,76958,188000,105000,70139,6072,91000,45896,54742,60000,148261,38776,118000,120000,138350,110000,130800,21669,412000,45618,62726,49268,190200,105000,91237,62726,42197,82528,150000,235000,53192,100000,5409,270000,80000,79197,140000,54238,47282,153667,28476,59102,110000,170000,80000,88654,76833,19609,276000,29751,89294,12000,450000,70000,95746,75000,150000,36259,62000,73000,51519,187442,115000,150000,30428,94564,113476,103160,12000,45391,225000,50000,40189,90000,200000,60000,200000,50000,110037,10354,151000,120000,9466,20000,40570,100000,49646,38400,24000,100000,90000,63711,77364,220000,80000,135000,240000,150000,82500,100000,82744,62649,90000,153000,160000,168000,150000,75774,13400,144000,127221,119059,423000,120000,125000,230000,85000,28369,63831,130026,165000,80000,250000,55000,150000,170000,82528,60000,235000,60757,174000,2859,40038,81000,5679,22611,90734,26005,61896,12000,4000,50000,69741,76833,74000,152000,21844,18000,174000,96113,147000,9272,24342,54094,90000,61467,195 ...
